# %% [markdown]
# ## Lecture 3: Lists, Tuples, Sets and Dictionaries

# %%
digits = [1,2,3,34,2,3,4]
print(digits)
# Out:
# [1, 2, 3, 34, 2, 3, 4]

# %%
type(digits)
# Out:
# list

# %%
list('djksjs')
# Out:
# ['d', 'j', 'k', 's', 'j', 's']

# %%
digits
# Out:
# [1, 2, 3, 34, 2, 3, 4]

# %%
digits[0]
# Out:
# 1

# %%
digits[3]
# Out:
# 34

# %%
digits
# Out:
# [1, 2, 3, 34, 2, 3, 4]

# %%
digits[-1]
# Out:
# 4

# %%
# digits: range of indexies = {0,...,6, -1,...,-7}
digits[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # digits: range of indexies = {0,...,6, -1,...,-7}
# ----> 2 digits[7]
#
# IndexError: list index out of range

# %%
digits[-8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 digits[-8]
#
# IndexError: list index out of range

# %%
digits[1] = 'new digit'
digits
# Out:
# [1, 'new digit', 3, 34, 2, 3, 4]

# %%
# explain 
a = [1,2]
b = a
b[0]='new'
print(a)
print(b)
# Out:
# ['new', 2]
# ['new', 2]

# %%
models = ['linear','rdforest','kmean','knn']

# %%
models[1]
# Out:
# 'rdforest'

# %%
models[-1]
# Out:
# 'knn'

# %%
models[-2]
# Out:
# 'kmean'

# %%
models
# Out:
# ['linear', 'rdforest', 'kmean', 'knn']

# %%
models[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 models[4]
#
# IndexError: list index out of range

# %%
model[-5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model[-5]
#
# NameError: name 'model' is not defined

# %%
models[0] = 'linear_regression'
models
# Out:
# ['linear_regression', 'rdforest', 'kmean', 'knn']

# %%
models.append('dbscan')
models
# Out:
# ['linear_regression', 'rdforest', 'kmean', 'knn', 'dbscan', 'dbscan']

# %%
len(models)
# Out:
# 6

# %%
print(models)
# Out:
# ['linear_regression', 'rdforest', 'kmean', 'knn', 'dbscan', 'dbscan']

# %%
len('sfsfsffd')
# Out:
# 8

# %%
models
# Out:
# ['linear_regression', 'rdforest', 'kmean', 'knn', 'dbscan', 'dbscan']

# %%
models.insert(1,'dbscan')
print(models)
# Out:
# ['linear_regression', 'dbscan', 'rdforest', 'kmean', 'knn', 'dbscan', 'dbscan']

# %%
models.insert(-1,'dbscan_end')
print(models)
# Out:
# ['linear_regression', 'dbscan', 'rdforest', 'kmean', 'knn', 'dbscan', 'dbscan_end', 'dbscan']

# %%
del models[-2]
print(models)
# Out:
# ['linear_regression', 'dbscan', 'rdforest', 'kmean', 'knn', 'dbscan', 'dbscan']

# %%
models.pop()
print(models)
# Out:
# ['linear_regression', 'dbscan', 'rdforest', 'kmean', 'knn', 'dbscan']

# %%
models.pop(-3)
print(models)
# Out:
# ['linear_regression', 'dbscan', 'rdforest', 'knn', 'dbscan']

# %%
models.remove('dbscan')
print(models)
# Out:
# ['linear_regression', 'rdforest', 'knn', 'dbscan']

# %% [markdown]
# **3-4. Guest List:** If you could invite anyone, living or deceased, to dinner, who
# would you invite? Make a list that includes at least three people you’d like to
# invite to dinner. Then use your list to print a message to each person, inviting
# them to dinner.

# %% [markdown]
# **3-5. Changing Guest List:** You just heard that one of your guests can’t make the
# dinner, so you need to send out a new set of invitations. You’ll have to think of
# someone else to invite.
# + Start with your program from Exercise 3-4. Add a print() call at the end
# of your program stating the name of the guest who can’t make it.
# - Modify your list, replacing the name of the guest who can’t make it with
# the name of the new person you are inviting.
# * Print a second set of invitation messages, one for each person who is still
# in your list.

# %% [markdown]
# **3-6. More Guests:** You just found a bigger dinner table, so now more space is
# available. Think of three more guests to invite to dinner.
# + Start with your program from Exercise 3-4 or Exercise 3-5. Add a print()
# call to the end of your program informing people that you found a bigger
# dinner table.
# + Use insert() to add one new guest to the beginning of your list.
# + Use insert() to add one new guest to the middle of your list.
# + Use append() to add one new guest to the end of your list.
# + Print a new set of invitation messages, one for each person in your list

# %%
cars = ['bmw', 'kia','toyota','honda']
sorted(cars)
# Out:
# ['bmw', 'honda', 'kia', 'toyota']

# %%
print(cars)
# Out:
# ['bmw', 'kia', 'toyota', 'honda']

# %%
cars = ['bmw', 'kia','toyota','honda']
sorted(cars,reverse=True)
# Out:
# ['toyota', 'kia', 'honda', 'bmw']

# %%
sorted([1,2,5,1])
# Out:
# [1, 1, 2, 5]

# %%
cars = ['bmw', 'kia','toyota','honda']
print(cars.sort())
print(cars)
# Out:
# None
# ['bmw', 'honda', 'kia', 'toyota']

# %%
alist = [[1],'djdjsjsjsdjjfjsjfjs','3424','we','aaaaaa','ewredddddsss']
sorted(alist, key = lambda x: len(x))
# Out:
# [[1], 'we', '3424', 'aaaaaa', 'ewredddddsss', 'djdjsjsjsdjjfjsjfjs']

# %%
alist1 = [['a',3],['b',1],['a',10],['w',1]]
sorted(alist1)
# Out:
# [['a', 3], ['a', 10], ['b', 1], ['w', 1]]

# %%
alist1 = [['a',3],['b',1],['a',10],['w',1]]
sorted(alist1, key = lambda x: x[0])
# Out:
# [['a', 3], ['a', 10], ['b', 1], ['w', 1]]

# %%
alist1 = [['a',3],['b',1],['a',10],['w',1]]
sorted(alist1, key = lambda x: x[1])
# Out:
# [['b', 1], ['w', 1], ['a', 3], ['a', 10]]

# %%
type(alist)
# Out:
# list

# %%
list('sdfsfsf')
# Out:
# ['s', 'd', 'f', 's', 'f', 's', 'f']

# %%
int('2')
# Out:
# 2

# %%
bool(1)
# Out:
# True

# %%
list(range(1,5))
# Out:
# [1, 2, 3, 4]

# %%
list(range(1,5))[0]
# Out:
# 1

# %%
squares = []
for i in range(1,11):
    squares.append(i**2)

print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
digits = [1,2,3,2,4,34,3,34,2,3,4,2]
print(sum(digits)/len(digits))
# Out:
# 7.833333333333333

# %%
digits.sort()
print(digits)
# Out:
# [1, 2, 2, 2, 2, 3, 3, 3, 4, 4, 34, 34]

# %%
even = len(digits)/2 ==len(digits)//2
odd = len(digits)/2 !=len(digits)//2
mid = len(digits)//2
print('median: ', even*((digits[mid-1]+digits[mid]))/2 + odd*(digits[mid]))
# Out:
# median:  3.0

# %%
2323*True
# Out:
# 2323

# %%
2323*False
# Out:
# 0

# %%
dir(digits)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
squares = [i**2 for i in range(1,11)]
squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
squares = [i**2 for i in range(1,11) if i%3==0]
squares
# Out:
# [9, 36, 81]

# %%
alist = [4*5**i for i in range(1,5)]
alist
# Out:
# [20, 100, 500, 2500]

# %%
alist = [1,2,3]
blist = alist
blist[1] = 'new'
print(alist)
print(blist)
# Out:
# [1, 'new', 3]
# [1, 'new', 3]

# %%
alist = [1,2,3]
blist = alist[:] # slicing = shalow copy
blist[1] = 'new'
print(alist)
print(blist)
# Out:
# [1, 2, 3]
# [1, 'new', 3]

# %%
alist = [1,[2],3]
blist = alist[:] # slicing = shalow copy
blist[1][0] = 'new'
print(alist)
print(blist)
# Out:
# [1, ['new'], 3]
# [1, ['new'], 3]

# %%
alist = [1,[2],3]
blist = alist[:]
type(blist[1])
# Out:
# list

# %%
list('243242sdf4')
# Out:
# ['2', '4', '3', '2', '4', '2', 's', 'd', 'f', '4']

# %%
atuple = (122,3,1,2)
atuple
# Out:
# (122, 3, 1, 2)

# %%
type(atuple)
# Out:
# tuple

# %%
tuple([1,2,3])
# Out:
# (1, 2, 3)

# %%
aset = {1,2,'342','d',(1,2)}
aset
# Out:
# {(1, 2), 1, 2, '342', 'd'}

# %%
type(aset)
# Out:
# set

# %%
set([1,2,3])
# Out:
# {1, 2, 3}

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
text = '''The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!'''

# %%
len(text)
# Out:
# 856

# %%
len(set(text))
# Out:
# 45

# %%
print(text)
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
#normalize
text_norm = text.lower()
special_char = {'.','*',',','!','-'}
for char in special_char:
    text_norm = text_norm.replace(char, ' ')
print(text_norm)
# Out:
# the zen of python  by tim peters
#
# beautiful is better than ugly
# explicit is better than implicit
# simple is better than complex
# complex is better than complicated
# flat is better than nested
# sparse is better than dense
# readability counts
# special cases aren't special enough to break the rules
# although practicality beats purity
# errors should never pass silently
# unless explicitly silenced
# in the face of ambiguity  refuse the temptation to guess
# there should be one   and preferably only one   obvious way to do it
# although that way may not be obvious at first unless you're dutch
# now is better than never
# although never is often better than  right  now
# if the implementation is hard to explain  it's a bad idea
# if the implementation is easy to explain  it may be a good idea
# namespaces are one honking great idea    let's do more of those

# %%
#count frequency
words = text_norm.split()
unique_word = set(words)
fre_word = [] # [(word, fre),....]
for w in unique_word:
    fre_word.append((w,words.count(w)))
fre_word
# Out:
# [('dutch', 1),
#  ('by', 1),
#  ('one', 3),
#  ('readability', 1),
#  ('than', 8),
#  ('explain', 2),
#  ('practicality', 1),
#  ('obvious', 2),
#  ('unless', 2),
#  ('silenced', 1),
#  ('in', 1),
#  ('counts', 1),
#  ('guess', 1),
#  ('break', 1),
#  ('more', 1),
#  ('tim', 1),
#  ('do', 2),
#  ('better', 8),
#  ('rules', 1),
#  ('errors', 1),
#  ('special', 2),
#  ('ambiguity', 1),
#  ('there', 1),
#  ('is', 10),
#  ("it's", 1),
#  ('zen', 1),
#  ('a', 2),
#  ('enough', 1),
#  ('beats', 1),
#  ('honking', 1),
#  ('it', 2),
#  ('dense', 1),
#  ('of', 3),
#  ('simple', 1),
#  ('idea', 3),
#  ('not', 1),
#  ('silently', 1),
#  ('implicit', 1),
#  ('face', 1),
#  ('good', 1),
#  ('if', 2),
#  ('that', 1),
#  ('complex', 2),
#  ('complicated', 1),
#  ('often', 1),
#  ('implementation', 2),
#  ('although', 3),
#  ('bad', 1),
#  ('never', 3),
#  ('easy', 1),
#  ('python', 1),
#  ('refuse', 1),
#  ('to', 5),
#  ("you're", 1),
#  ('should', 2),
#  ('temptation', 1),
#  ('flat', 1),
# ...

# %%
sorted(fre_word,key=lambda x: x[1], reverse= True)
# Out:
# [('is', 10),
#  ('than', 8),
#  ('better', 8),
#  ('the', 6),
#  ('to', 5),
#  ('one', 3),
#  ('of', 3),
#  ('idea', 3),
#  ('although', 3),
#  ('never', 3),
#  ('be', 3),
#  ('explain', 2),
#  ('obvious', 2),
#  ('unless', 2),
#  ('do', 2),
#  ('special', 2),
#  ('a', 2),
#  ('it', 2),
#  ('if', 2),
#  ('complex', 2),
#  ('implementation', 2),
#  ('should', 2),
#  ('now', 2),
#  ('way', 2),
#  ('may', 2),
#  ('dutch', 1),
#  ('by', 1),
#  ('readability', 1),
#  ('practicality', 1),
#  ('silenced', 1),
#  ('in', 1),
#  ('counts', 1),
#  ('guess', 1),
#  ('break', 1),
#  ('more', 1),
#  ('tim', 1),
#  ('rules', 1),
#  ('errors', 1),
#  ('ambiguity', 1),
#  ('there', 1),
#  ("it's", 1),
#  ('zen', 1),
#  ('enough', 1),
#  ('beats', 1),
#  ('honking', 1),
#  ('dense', 1),
#  ('simple', 1),
#  ('not', 1),
#  ('silently', 1),
#  ('implicit', 1),
#  ('face', 1),
#  ('good', 1),
#  ('that', 1),
#  ('complicated', 1),
#  ('often', 1),
#  ('bad', 1),
#  ('easy', 1),
#  ('python', 1),
# ...

# %%
scores = {'Hoang':8, "lan":7, ("Mai", "Hoa"):10}
type(scores)
# Out:
# dict

# %%
dict([(1,2),(3,4)])
# Out:
# {1: 2, 3: 4}

# %%
scores = {'Hoang':8, "lan":7, 'Hoang':10}
scores
# Out:
# {'Hoang': 10, 'lan': 7}

# %%
scores['Hoang']
# Out:
# 10

# %%
scores['Hung'] = 8
scores
# Out:
# {'Hoang': 10, 'lan': 7, 'Hung': 8}

# %%
scores['Hoa'] = 10
scores
# Out:
# {'Hoang': 10, 'lan': 7, 'Hung': 8, 'Hoa': 10}

# %%
scores['Mai'] = [7,9]
scores
# Out:
# {'Hoang': 10, 'lan': 7, 'Hung': 8, 'Hoa': 10, 'Mai': [7, 9]}

# %%
try:
    scores['Long']
except:
    print('No key')
# Out:
# No key

# %%
scores
# Out:
# {'Hoang': 10, 'lan': 7, 'Hung': 8, 'Hoa': 10, 'Mai': [7, 9]}

# %%
scores.get('Long', 'No key')
# Out:
# 'No key'

# %%
scores.get('Hung', 'No key')
# Out:
# 8

# %%
scores.items()
# Out:
# dict_items([('Hoang', 10), ('lan', 7), ('Hung', 8), ('Hoa', 10), ('Mai', [7, 9])])

# %%
for item in scores.items():
    print(item)
# Out:
# ('Hoang', 10)
# ('lan', 7)
# ('Hung', 8)
# ('Hoa', 10)
# ('Mai', [7, 9])

# %%
for key, val in scores.items(): #key, val = key, value
    print('Key: ', key, '___Valule: ',val)
# Out:
# Key:  Hoang ___Valule:  10
# Key:  lan ___Valule:  7
# Key:  Hung ___Valule:  8
# Key:  Hoa ___Valule:  10
# Key:  Mai ___Valule:  [7, 9]

# %%
for item in scores:
    print(item)
# Out:
# Hoang
# lan
# Hung
# Hoa
# Mai

# %%
scores.keys()
# Out:
# dict_keys(['Hoang', 'lan', 'Hung', 'Hoa', 'Mai'])

# %%
for item in scores.keys():
    print(item)
# Out:
# Hoang
# lan
# Hung
# Hoa
# Mai

# %%
scores.values()
# Out:
# dict_values([10, 7, 8, 10, [7, 9]])

# %%
import numpy as np
import pandas as pd

# %%
data = {'cus_ID':range(5), "clv": [2312,32,200,400,300]}
df = pd.DataFrame(data)
df
# Out:
#    cus_ID   clv
# 0       0  2312
# 1       1    32
# 2       2   200
# 3       3   400
# 4       4   300

# %%
customers = {
    "C001": {
        "name": "Nguyễn Văn A",
        "age": 32,
        "gender": "Nam",
        "city": "Hà Nội",
        "total_spent": 12500000,
        "num_orders": 8
    },
    "C002": {
        "name": "Trần Thị B",
        "age": 27,
        "gender": "Nữ",
        "city": "TP.HCM",
        "total_spent": 8200000,
        "num_orders": 5
    },
    "C003": {
        "name": "Lê Văn C",
        "age": 45,
        "gender": "Nam",
        "city": "Đà Nẵng",
        "total_spent": 15300000,
        "num_orders": 12
    }
}
pd.DataFrame(customers)
# Out:
#                      C001        C002      C003
# name         Nguyễn Văn A  Trần Thị B  Lê Văn C
# age                    32          27        45
# gender                Nam          Nữ       Nam
# city               Hà Nội      TP.HCM   Đà Nẵng
# total_spent      12500000     8200000  15300000
# num_orders              8           5        12

# %%
scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 scores
#
# NameError: name 'scores' is not defined

# %%
del scores['Mai']
scores
# Out:
# {'Hoang': 10, 'lan': 7, 'Hung': 8, 'Hoa': 10}

# %%
dir(scores)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dir(scores)
#
# NameError: name 'scores' is not defined

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
text = '''The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!'''

# %%
#normalize
text_norm = text.lower()
special_char = {',','.','!','-','*'}
for char in special_char:
    text_norm = text_norm.replace(char, ' ')
#print(text_norm)

# %%
#frequency
words = text_norm.split()
fre_word = dict() # {word:frequency}
for w in words:
    if w in fre_word:
        fre_word[w] += 1
    else:
        fre_word[w] = 1
fre_word
# Out:
# {'the': 6,
#  'zen': 1,
#  'of': 3,
#  'python': 1,
#  'by': 1,
#  'tim': 1,
#  'peters': 1,
#  'beautiful': 1,
#  'is': 10,
#  'better': 8,
#  'than': 8,
#  'ugly': 1,
#  'explicit': 1,
#  'implicit': 1,
#  'simple': 1,
#  'complex': 2,
#  'complicated': 1,
#  'flat': 1,
#  'nested': 1,
#  'sparse': 1,
#  'dense': 1,
#  'readability': 1,
#  'counts': 1,
#  'special': 2,
#  'cases': 1,
#  "aren't": 1,
#  'enough': 1,
#  'to': 5,
#  'break': 1,
#  'rules': 1,
#  'although': 3,
#  'practicality': 1,
#  'beats': 1,
#  'purity': 1,
#  'errors': 1,
#  'should': 2,
#  'never': 3,
#  'pass': 1,
#  'silently': 1,
#  'unless': 2,
#  'explicitly': 1,
#  'silenced': 1,
#  'in': 1,
#  'face': 1,
#  'ambiguity': 1,
#  'refuse': 1,
#  'temptation': 1,
#  'guess': 1,
#  'there': 1,
#  'be': 3,
#  'one': 3,
#  'and': 1,
#  'preferably': 1,
#  'only': 1,
#  'obvious': 2,
#  'way': 2,
#  'do': 2,
#  'it': 2,
#  'that': 1,
#  'may': 2,
#  'not': 1,
#  'at': 1,
#  'first': 1,
#  "you're": 1,
# ...

# %%
len(fre_word)
# Out:
# 85

# %%
x = 10
if x>2:
    pass
elif x>3:
        print(x)
# Out:
# 10
# 10

# %%
x = 10
if x>2:
    print(x)
elif x>3:
    print(x)
# Out:
# 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age = int(input('How old are you?'))
discount = 0
if age<10:
    discount = 0.15
elif age<18:
    discount = 0.08
elif age<23:
    discount = 0.05
elif age<=60:
    discount = 0.02
else: 
    discount = 0.25
p = 200
print(f'Đơn hàng được giảm {discount*100} %')
print(f'Tổng đơn hàng là: {p}, Số tiền cần thanh toán sau giảm giá là: {p*(1-discount)}')
# Out:
# Đơn hàng được giảm 2.0 %
# Tổng đơn hàng là: 200, Số tiền cần thanh toán sau giảm giá là: 196.0
