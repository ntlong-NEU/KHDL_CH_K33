# %% [markdown]
# ## Lecture 3: Lists, Tuples, Sets and Dictionaries

# %%
digits = [1,2,3,34,2,3,4]
print(digits)
# Out:
# [1, 2, 3, 34, 2, 3, 4]

# %%
type(digits)
# Out:
# list

# %%
list('djksjs')
# Out:
# ['d', 'j', 'k', 's', 'j', 's']

# %%
digits
# Out:
# [1, 2, 3, 34, 2, 3, 4]

# %%
digits[0]
# Out:
# 1

# %%
digits[3]
# Out:
# 34

# %%
digits
# Out:
# [1, 2, 3, 34, 2, 3, 4]

# %%
digits[-1]
# Out:
# 4

# %%
# digits: range of indexies = {0,...,6, -1,...,-7}
digits[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # digits: range of indexies = {0,...,6, -1,...,-7}
# ----> 2 digits[7]
#
# IndexError: list index out of range

# %%
digits[-8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 digits[-8]
#
# IndexError: list index out of range

# %%
digits[1] = 'new digit'
digits
# Out:
# [1, 'new digit', 3, 34, 2, 3, 4]

# %%
# explain 
a = [1,2]
b = a
b[0]='new'
print(a)
print(b)
# Out:
# ['new', 2]
# ['new', 2]
