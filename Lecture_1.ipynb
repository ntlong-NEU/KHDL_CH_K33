# %% [markdown]
# ## Lecture 1: Getting started with VS code and jupyter notebook
#
# 1. Section 1
#
# 2. Section 2
#
# + Items 1
# * Items 2
# - Formula: $x^2+2x+1 = 0$

# %%
print('Hello python')
# Out:
# Hello python

# %%
# Giới thiệu các lệnh cơ bản nhất của Python

# In ra màn hình
print("Xin chào Python")

# Biến và kiểu dữ liệu
x = 10          # int
y = 3.5         # float
name = "An"     # str
is_ready = True # bool

# Toán tử cơ bản
sum_xy = x + y
prod = x * 2
power = x ** 2

# Cấu trúc dữ liệu cơ bản
lst = [1, 2, 3]
tpl = (1, 2, 3)
dct = {"a": 1, "b": 2}
st = {1, 2, 3}

# Vòng lặp và điều kiện
for i in lst:
    print("phần tử:", i)

if x > 5:
    print("x lớn hơn 5")
else:
    print("x không lớn hơn 5")

# Hàm
def add(a, b):
    return a + b

print("add(2,3) =", add(2, 3))

# List comprehension
squares = [n*n for n in range(5)]
print("squares =", squares)

# Xử lý ngoại lệ
try:
    print(10 / 0)
except ZeroDivisionError:
    print("Lỗi: chia cho 0")

# Đọc/ghi file (ví dụ)
with open("example.txt", "w") as f:
    f.write("Ví dụ đọc/ghi file\n")
with open("example.txt", "r") as f:
    print("Nội dung file:", f.read())
# Out:
# Xin chào Python
# phần tử: 1
# phần tử: 2
# phần tử: 3
# x lớn hơn 5
# add(2,3) = 5
# squares = [0, 1, 4, 9, 16]
# Lỗi: chia cho 0
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[2], line 50
#      48 # Đọc/ghi file (ví dụ)
#      49 with open("example.txt", "w") as f:
# ---> 50     f.write("Ví dụ đọc/ghi file\n")
#      51 with open("example.txt", "r") as f:
#      52     print("Nội dung file:", f.read())
#
# File ~\anaconda3\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u1ee5' in position 4: character maps to <undefined>

# %% [markdown]
# ![image.png](attachment:image.png)
